# %% [markdown]
# Tuples as Data Structures

# %%
a = [10, 20, 30]

# %%
a = (10, 20, 30)
b = 10, 20, 30

# %%
def print_tuple(t):
    for e in t:
        print(e)

# %%
print_tuple(10, 20, 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print_tuple(10, 20, 30)
#
# TypeError: print_tuple() takes 1 positional argument but 3 were given

# %%
print_tuple((10, 20, 30))
# Out:
# 10
# 20
# 30

# %%
a = 1, 2, 3, 4, 5, 6
a[2:5]
# Out:
# (3, 4, 5)

# %%
a = 'a', 10, 20

# %%
X, Y, Z = a

# %%
X, Y, Z
# Out:
# ('a', 10, 20)

# %%
a = 1, 2, 3, 4, 5
x, *other, y, z = a
x,y,z
# Out:
# (1, 4, 5)

# %%
other
# Out:
# [2, 3]

# %%
a[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
class Point2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __repr__(self):
        return f'{self.__class__.__name__}(x={self.x}, y={self.y})'

# %%
pt = Point2D(10,20)

# %%
id(pt)
# Out:
# 128426306357904

# %%
pt
# Out:
# Point2D(x=10, y=20)

# %%
a = Point2D(0,0), Point2D(10,20)

# %%
a[0].x = 100

# %%
a
# Out:
# (Point2D(x=100, y=0), Point2D(x=10, y=20))

# %%
a = (1, 2, 3)

# %%
a, id(a)
# Out:
# ((1, 2, 3), 128426307320640)

# %%
a = a+ (4, 5)

# %%
a, id(a)
# Out:
# ((1, 2, 3, 4, 5), 128426307537472)

# %%
pt1 = (0,0)
pt2 = (10, 20)

# %%
pt1, pt2
# Out:
# ((0, 0), (10, 20))

# %%
london = 'London', 'UK', 8_780_000
new_york = 'New York', 'USA', 8_500_000
beijing = 'Beijing', 'China', 21_000_000

# %%
cities = [london, new_york, beijing]

# %%
total = 0
for city in cities:
    total += city[2]

# %%
print(total)
# Out:
# 38280000

# %%
sum(city[2] for city in cities)
# Out:
# 38280000

# %%
from random import uniform
from math import sqrt

# %%
def random_shot(radius):
    random_x = uniform(-radius, radius)
    random_y = uniform(-radius, radius)
    if sqrt(random_x**2 + random_y**2) <= radius:
        is_in_circle = True
    else:
        is_in_circle = False
    return random_x, random_y, is_in_circle

# %%
num_attempts = 1000000
count_inside = 0
for i in range(num_attempts):
    *_, is_in_circle = random_shot(1)
    if is_in_circle:
        count_inside += 1
print(f'Pi is approximately: {4* count_inside / num_attempts}')
# Out:
# Pi is approximately: 3.139664

# %% [markdown]
# Named Tuples

# %%
class Point3D:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z

# %%
from collections import namedtuple

# %%
Point2D = namedtuple('Point2D', ['x', 'y'])

# %%
pt1 = Point2D(10, 20)

# %%
pt1
# Out:
# Point2D(x=10, y=20)

# %%
pt3d_1 = Point3D(10, 20, 30)

# %%
pt3d_1

# %%
pt2 = Point2D(10, 20)

# %%
pt2
# Out:
# Point2D(x=10, y=20)

# %%
Pt3D = Point3D

# %%
p = Pt3D(10, 20, 30)

# %%
p = Point3D(x=10, y=20, z=30)

# %%
p.x, p.y
# Out:
# (10, 20)

# %%
p = Point2D(x=10, y=20)
p
# Out:
# Point2D(x=10, y=20)

# %%
isinstance(p, tuple)
# Out:
# True

# %%
p = Point3D(x=10, y=20, z=30)

# %%
isinstance(p, tuple)
# Out:
# False

# %%
a = (10, 20)
b = (10, 20)

# %%
a is b
# Out:
# False

# %%
a == b
# Out:
# True

# %%
pt1 = Point2D(10, 20)
pt2 = Point2D(10, 20)

# %%
pt1 is pt2
# Out:
# False

# %%
pt1 == pt2
# Out:
# True

# %%
class Point3D:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
    def __repr__(self):
        return f'{self.__class__.__name__}(x = {self.x}, y = {self.y})'
    def __eq__(self, other):
        if isinstance(other, Point3D):
            return self.x == other.x and self.y == other.y and self.z == other.z
        else:
            return False

# %%
pt1 = Point3D(10, 20, 30)
pt2 = Point3D(10, 20, 30)

# %%
pt1 == pt2
# Out:
# True

# %%
pt1 = Point2D(10, 20) # named tuple
pt2 = Point3D(10, 20, 30)

# %%
max(pt1)
# Out:
# 20

# %%
max(pt2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 max(pt2)
#
# TypeError: 'Point3D' object is not iterable

# %%
def dot_product_3d(a, b):
    return a.x * b.x + a.y * b.y + a.z * b.z

# %%
pt1 = Point3D(1, 2, 3)
pt2 = Point3D(1, 1, 1)

# %%
dot_product_3d(pt1, pt2)
# Out:
# 6

# %%
a = (10, 20)
b = (10, 20)

# %%
list(zip(a, b))
# Out:
# [(10, 10), (20, 20)]

# %%
sum([e[0] * e[1] for e in zip(a,b)])
# Out:
# 500

# %%
def dot_product(a,b):
    return sum([e[0] * e[1] for e in zip(a,b)])

# %%
dot_product(a,b)
# Out:
# 500

# %%
Vector3D = namedtuple('Vector3D', 'x y z')

# %%
v1 = Vector3D(1, 2, 3)
v2 = Vector3D(1, 1, 1)
dot_product(v1, v2)
# Out:
# 6

# %%
v1
# Out:
# Vector3D(x=1, y=2, z=3)

# %%
v1.x
# Out:
# 1

# %%
v1.y
# Out:
# 2

# %%
Stock = namedtuple('Stock', '''Symbol
                                    year
                                    month
                                    day
                                    open
                                    high
                                    low
                                    close''')

# %%
djia = Stock('DJIA', 2018, 1, 25, 26_313, 26_458, 26_260, 26_393)

# %%
djia.close
# Out:
# 26393

# %%
for item in djia:
    print(item)
# Out:
# DJIA
# 2018
# 1
# 25
# 26313
# 26458
# 26260
# 26393

# %%
p = Point2D(10, 20)
x, y = p

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
djia
# Out:
# Stock(Symbol='DJIA', year=2018, month=1, day=25, open=26313, high=26458, low=26260, close=26393)

# %%
symbol, year, month, day, *_, close = djia

# %%
symbol, year, month, day, close
# Out:
# ('DJIA', 2018, 1, 25, 26393)

# %%
print(_)
# Out:
# [26313, 26458, 26260]

# %%
Person = namedtuple('Person', 'name age _ssn', rename = True)

# %%
Person._fields
# Out:
# ('name', 'age', '_2')

# %%
Point2D._fields
# Out:
# ('x', 'y')

# %%
Stock._fields
# Out:
# ('Symbol', 'year', 'month', 'day', 'open', 'high', 'low', 'close')

# %%
Stock._source
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 Stock._source
#
# AttributeError: type object 'Stock' has no attribute '_source'

# %%
d = djia._asdict()

# %%
d['close']
# Out:
# 26393

# %% [markdown]
# Named Tuples Modifying and Extending

# %%
from collections import namedtuple

# %%
Point2D = namedtuple('Point2D', 'x y')

# %%
pt = Point2D(10, 20)

# %%
pt[0]
# Out:
# 10

# %%
pt.x = 100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pt.x = 100
#
# AttributeError: can't set attribute

# %%
pt[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pt[0] = 100
#
# TypeError: 'Point2D' object does not support item assignment

# %%
id(pt)
# Out:
# 136989866124608

# %%
pt = Point2D(100, pt.y)

# %%
id(pt)
# Out:
# 136989866052032

# %%
Stock = namedtuple('Stock', '''Symbol
                                    year
                                    month
                                    day
                                    open
                                    high
                                    low
                                    close''')

# %%
djia = Stock('DJIA', 2018, 1, 25, 26_313, 26_458, 26_260, 26_393)

# %%
*values, _ = djia

# %%
values
# Out:
# ['DJIA', 2018, 1, 25, 26313, 26458, 26260]

# %%
values + [26_393]
# Out:
# ['DJIA', 2018, 1, 25, 26313, 26458, 26260, 26393]

# %%
values.append(26_393)

# %%
values
# Out:
# ['DJIA', 2018, 1, 25, 26313, 26458, 26260, 26393]

# %%
djia = Stock(*values)

# %%
djia
# Out:
# Stock(Symbol='DJIA', year=2018, month=1, day=25, open=26313, high=26458, low=26260, close=26393)

# %%
a = [1,2,3]

# %%
a = a + [4, 5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [1, 2, 3]

# %%
a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
a.extend([5, 6, 7])

# %%
values = djia[:7]

# %%
values + (100,)
# Out:
# ('DJIA', 2018, 1, 25, 26313, 26458, 26260, 100)

# %%
djia = Stock(*(values + (100,)))

# %%
djia = Stock(*values, 1000)

# %%
djia
# Out:
# Stock(Symbol='DJIA', year=2018, month=1, day=25, open=26313, high=26458, low=26260, close=1000)

# %%
print(id(djia))
djia = djia._replace(year = 2019, open = 10000)
# Out:
# 136989862888160

# %%
print(id(djia))
# Out:
# 136989862889168

# %%
djia
# Out:
# Stock(Symbol='DJIA', year=2019, month=1, day=25, open=10000, high=26458, low=26260, close=1000)

# %%
djia = Stock._make(values + (100,))

# %%
djia, id(djia)
# Out:
# (Stock(Symbol='DJIA', year=2018, month=1, day=25, open=26313, high=26458, low=26260, close=100),
#  136989862890176)

# %%
Point2D._fields
# Out:
# ('x', 'y')

# %%
Point2D._fields + ('z',)
# Out:
# ('x', 'y', 'z')

# %%
Point3D = namedtuple('Point3D',Point2D._fields + ('z',))

# %%
Point3D._fields
# Out:
# ('x', 'y', 'z')

# %%
pt
# Out:
# Point2D(x=100, y=20)

# %%
pt = Point3D._make(pt + (100,))

# %%
pt
# Out:
# Point3D(x=100, y=20, z=100)

# %%
pt = Point2D(100,20)

# %%
pt3d = Point3D(*pt, 100)

# %%
pt3d
# Out:
# Point3D(x=100, y=20, z=100)

# %%
Point3D.__doc__
# Out:
# 'Point3D(x, y, z)'

# %%
help(Point3D)
# Out:
# Help on class Point3D in module __main__:
#
# class Point3D(builtins.tuple)
#  |  Point3D(x, y, z)
#  |
#  |  Point3D(x, y, z)
#  |
#  |  Method resolution order:
#  |      Point3D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new dict which maps field names to their values.
#  |
#  |  _replace(self, /, **kwds)
#  |      Return a new Point3D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Point3D object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
# ...

# %%
Point3D.x.__doc__
# Out:
# 'Alias for field number 0'

# %%
from collections import namedtuple

# %%
Point2D = namedtuple('Point2D', 'x y')

# %%
Point2D.__doc__
# Out:
# 'Point2D(x, y)'

# %%
Point2D.x.__doc__
# Out:
# 'Alias for field number 0'

# %%
Point2D.y.__doc__
# Out:
# 'Alias for field number 1'

# %%
help(Point2D)
# Out:
# Help on class Point2D in module __main__:
#
# class Point2D(builtins.tuple)
#  |  Point2D(x, y)
#  |
#  |  Point2D(x, y)
#  |
#  |  Method resolution order:
#  |      Point2D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new dict which maps field names to their values.
#  |
#  |  _replace(self, /, **kwds)
#  |      Return a new Point2D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Point2D object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
# ...

# %%
Point2D.__doc__ = '2D cartesian coordinates'

# %%
Point2D.x.__doc__ = 'x coordinate'

# %%
Point2D.y.__doc__ = 'y coordinate'

# %%
help(Point2D)
# Out:
# Help on class Point2D in module __main__:
#
# class Point2D(builtins.tuple)
#  |  Point2D(x, y)
#  |
#  |  2D cartesian coordinates
#  |
#  |  Method resolution order:
#  |      Point2D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new dict which maps field names to their values.
#  |
#  |  _replace(self, /, **kwds)
#  |      Return a new Point2D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Point2D object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
# ...

# %%
vector2D = namedtuple('Vector2D', 'x1 y1 x2 y2 orgin_x origin_y')

# %%
vector_zero= vector2D(0, 0, 0, 0, 0, 0)

# %%
v2 = vector_zero._replace(x1 = 10, y1 = 10, x2 = 20, y2 = 20)

# %%
v2, vector_zero
# Out:
# (Vector2D(x1=10, y1=10, x2=20, y2=20, orgin_x=0, origin_y=0),
#  Vector2D(x1=0, y1=0, x2=0, y2=0, orgin_x=0, origin_y=0))

# %%
vector_altzero= vector2D(0, 0, 0, 0, -10, -10)

# %%
def func(a, b=10, c=20):
    print(a, b, c)

# %%
func(1)
# Out:
# 1 10 20

# %%
func.__defaults__ = (100, 200, 300)

# %%
help(func)
# Out:
# Help on function func in module __main__:
#
# func(a=100, b=200, c=300)

# %%
vector2D.__new__.__defaults__

# %%
help(vector2D)
# Out:
# Help on class Vector2D in module __main__:
#
# class Vector2D(builtins.tuple)
#  |  Vector2D(x1, y1, x2, y2, orgin_x, origin_y)
#  |
#  |  Vector2D(x1, y1, x2, y2, orgin_x, origin_y)
#  |
#  |  Method resolution order:
#  |      Vector2D
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new dict which maps field names to their values.
#  |
#  |  _replace(self, /, **kwds)
#  |      Return a new Vector2D object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Vector2D object from a sequence or iterable
#  |
# ...

# %%
vector2D.__new__.__defaults__ = (0,0)

# %%
v1 = vector2D(10, 10, 20, 20)

# %%
v1
# Out:
# Vector2D(x1=10, y1=10, x2=20, y2=20, orgin_x=0, origin_y=0)

# %% [markdown]
# named tuple applications

# %%
from random import randint, random

# %%
color = random_color()
color
# Out:
# (215, 230, 21, 0.3)

# %%
Color = namedtuple('Color', 'red blue green alpha')

# %%
def random_color():
    red = randint(0, 255)
    blue = randint(0, 255)
    green = randint(0, 255)
    alpha = round(random(), 2)
    return Color(red, blue, green, alpha)

# %%
color = random_color()

# %%
color._fields # allows us to see the propertioes in pycharm by using a named tupel insstead of  a standard tuple
# Out:
# ('red', 'blue', 'green', 'alpha')

# %% [markdown]
# named tuple - alternative to dictionaries

# %%
data_dict = dict(key1 = 100, key2 = 200, key3 = 300)

# %%
data_dict['key1']
# Out:
# 100

# %%
data = namedtuple('Data', 'key1 key2 key3')

# %%
Data = namedtuple('Data', data_dict.keys())

# %%
Data._fields
# Out:
# ('key1', 'key2', 'key3')

# %%
d1 = Data(*data_dict.values())

# %%
d1
# Out:
# Data(key1=100, key2=200, key3=300)

# %%
d2 = Data(key1 = 10, key2 = 20, key3 = 30)

# %%
d2
# Out:
# Data(key1=10, key2=20, key3=30)

# %%
Data = namedtuple('Data', 'key3 key2 key1')

# %%
d2 = Data(**data_dict)

# %%
d2
# Out:
# Data(key3=300, key2=200, key1=100)

# %%
key_name = 'key2'

# %%
getattr(d2, key_name) # named tuple way of retrieving key
# Out:
# 200

# %%
data_dict[key_name]
# Out:
# 200

# %%
d2.key_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 d2.key_name
#
# AttributeError: 'Data' object has no attribute 'key_name'

# %%
data_dict.get('key10', None)

# %%
getattr(d2, 'key10', None)

# %%
data_list = [{'key1': 1, 'key2': 2}, {'key1': 3, 'key2': 4}, 
             {'key1': 5, 'key2': 6, 'key3': 7}, {'key2': 100}]

# %%
keys = set()

# %%
keys.add(1)

# %%
keys.add(2)

# %%
keys
# Out:
# {1, 2}

# %%
keys = set()
for d in data_list:
    for key in d.keys():
        keys.add(key)
print(keys)
# Out:
# {'key3', 'key1', 'key2'}

# %%
keys= {key for dict in data_list for key in dict.keys()}

# %%
keys
# Out:
# {'key1', 'key2', 'key3'}

# %%
Struct = namedtuple('Struct', sorted(keys))

# %%
Struct._fields
# Out:
# ('key1', 'key2', 'key3')

# %%
Struct.__new__.__defaults__ = (None, )* len(Struct._fields)

# %%
help(Struct)
# Out:
# Help on class Struct in module __main__:
#
# class Struct(builtins.tuple)
#  |  Struct(key1=None, key2=None, key3=None)
#  |
#  |  Struct(key1, key2, key3)
#  |
#  |  Method resolution order:
#  |      Struct
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new dict which maps field names to their values.
#  |
#  |  _replace(self, /, **kwds)
#  |      Return a new Struct object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable) from builtins.type
#  |      Make a new Struct object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
# ...

# %%
tuple_list = []
for dict_ in data_list:
    tuple_list.append(Struct(**dict_))
print(tuple_list)
# Out:
# [Struct(key1=1, key2=2, key3=None), Struct(key1=3, key2=4, key3=None), Struct(key1=5, key2=6, key3=7), Struct(key1=None, key2=100, key3=None)]

# %%
def tuplify_dicts(dicts):
    keys = {key for dict_ in dicts for key in dict_.keys()}
    Struct = namedtuple('Struct', sorted(keys), rename = True) # we set rename = True tol avoid errors if key name is not valid
    Struct.__new__.__defaults__ = (None,) * len(Struct._fields)
    return [Struct(**dict_) for dict_ in dicts]

# %%
tuple_list = tuplify_dicts(data_list)

# %%
tuple_list
# Out:
# [Struct(key1=1, key2=2, key3=None),
#  Struct(key1=3, key2=4, key3=None),
#  Struct(key1=5, key2=6, key3=7),
#  Struct(key1=None, key2=100, key3=None)]
