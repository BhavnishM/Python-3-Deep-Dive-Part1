# %% [markdown]
# Positional and keyword arguments

# %%
def my_func(a, b, c):
    print("a = {0}, b = {1}, c = {2}".format(a,b,c))

# %%
my_func(1,2,3)
# Out:
# a = 1, b = 2, c = 3

# %%
def my_func(a, b=2, c):
    print("a = {0}, b = {1}, c = {2}".format(a,b,c))
# Out:
#   Cell In[5], line 1
#     def my_func(a, b=2, c):
#                          ^
# SyntaxError: non-default argument follows default argument

# %%
def my_func(a, b=2, c=3):
    print("a = {0}, b = {1}, c = {2}".format(a,b,c))

# %%
my_func(10,20,30)
# Out:
# a = 10, b = 20, c = 30

# %%
my_func(10,20)
# Out:
# a = 10, b = 20, c = 3

# %%
my_func(10)
# Out:
# a = 10, b = 2, c = 3

# %%
my_func(b = 10, a = 20)
# Out:
# a = 20, b = 10, c = 3

# %% [markdown]
# Unpacking Iterables

# %%
a = (1)
type(a)
# Out:
# int

# %%
a = ('1',)
type(a)
# Out:
# tuple

# %%
a = ()
type(a)
# Out:
# tuple

# %%
a,b,c = [1, 'a', 3.14]

# %%
a,b,c
# Out:
# (1, 'a', 3.14)

# %%
a, b =(1, 2)

# %%
a, b
# Out:
# (1, 2)

# %%
#because rhs is evaluated first you can do
d = {'a':1, 'b':2, 'c':3, 'd':4}
a, b, c, d = d
a, b,c, d
# Out:
# ('a', 'b', 'c', 'd')

# %%
d = {'a':1, 'b':2, 'c':3, 'd':4}
d, a, b, c= d
a, b,c, d
# Out:
# ('b', 'c', 'd', 'a')

# %%
d = {'a':1, 'b':2, 'c':3, 'd':4}
for e in d.values():
    print(e)
# Out:
# 1
# 2
# 3
# 4

# %%
a,b, c, d = d.values()

# %%
a,b, c, d
# Out:
# (1, 2, 3, 4)

# %%
d = {'a':1, 'b':2, 'c':3, 'd':4}
for e in d.items():
    a, b = e
    print('key = {0}, value = {1}'.format(a, b))
# Out:
# key = a, value = 1
# key = b, value = 2
# key = c, value = 3
# key = d, value = 4

# %%
to_unpack = [1,2,3,'python']

# %%
a,b,c,d = to_unpack[0], to_unpack[1:3], to_unpack[3][0],[*to_unpack[3][1:]]

# %%
a,b,c,d
# Out:
# (1, [2, 3], 'p', ['y', 't', 'h', 'o', 'n'])

# %%
l = [1,2,3,4,5,6]
a = l[0]
b = l[1:]
print(a)
print(b)
# Out:
# 1
# [2, 3, 4, 5, 6]

# %%
a,*b = l
a,b
# Out:
# (1, [2, 3, 4, 5, 6])

# %%
a,b,c = 'XYZ'
a,b,c
# Out:
# ('X', 'Y', 'Z')

# %% [markdown]
# extended unpacking

# %%
s = 'python'
a,b,*c, d = s
a,b, c, d
# Out:
# ('p', 'y', ['t', 'h', 'o'], 'n')

# %%
s = 'python'
a, b, c, d = s[0], s[1], s[2:-1], s[-1]

# %%
a, b, c, d
# Out:
# ('p', 'y', 'tho', 'n')

# %%
l1 = [1,2,3]
l2 = [4,5,6]
l = [*l1, *l2]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1 = [1,2,3]
s1 = {'x', 'y', 'z'}
l = [*l1, *s1]
l
# Out:
# [1, 2, 3, 'x', 'z', 'y']

# %%
s1 = 'abc'
s2 = 'cde'
s = [*s1, *s2]
s
# Out:
# ['a', 'b', 'c', 'c', 'd', 'e']

# %%
s1 = 'abc'
s2 = 'cde'
s = {*s1, *s2}
s
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
s1 = {1,2,3}
s2 = {3,4,5}
s = {*s1, *s2}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
[*s1, *s2] # set unpacking retains duplicates
# Out:
# [1, 2, 3, 3, 4, 5]

# %%
s3 = {7,8,3}
s4 = {0,9,5}
s1.union(s2, s3, s4)
# Out:
# {0, 1, 2, 3, 4, 5, 7, 8, 9}

# %%
d1 = {'key1':1, 'key2':2}
d2 = {'key2':3, 'key4':4}
[*d1, *d2]
# Out:
# ['key1', 'key2', 'key2', 'key4']

# %%
{**d1, **d2}
# Out:
# {'key1': 1, 'key2': 3, 'key4': 4}

# %%
{'a':1, 'b':2, **d1, 'c':3}
# Out:
# {'a': 1, 'b': 2, 'key1': 1, 'key2': 2, 'c': 3}

# %%
a,b,(c,d) = [1,2,'XY']
a,b,c,d
# Out:
# (1, 2, 'X', 'Y')

# %%
a,b,(c,d,*e) = [1,2,'python']

# %%
a,b,*f,(c,d,*e) = [1,2,3,4,5,6,'python']

# %%
a,b,c,d,e,f
# Out:
# (1, 2, 'p', 'y', ['t', 'h', 'o', 'n'], [3, 4, 5, 6])

# %%
a,b,*c = 10, 20, 'a', 'b'

# %%
a,b,c
# Out:
# (10, 20, ['a', 'b'])

# %% [markdown]
# *args as a function parameter

# %%
def func1(a,b,*args):
    return a, b, args

# %%
func1(10,20)
# Out:
# (10, 20, ())

# %%
func1(10,20,1,2,3)
# Out:
# (10, 20, (1, 2, 3))

# %%
def avg(*args):
    count = len(args)
    total = sum(args)
    return count and total/count

# %%
avg(2,2,4,4)
# Out:
# 3.0

# %%
avg()
# Out:
# 0

# %%
def avg(a,*args):
    count = len(args) + 1
    total = sum(args) + a
    return total/count

# %%
avg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 avg()
#
# TypeError: avg() missing 1 required positional argument: 'a'

# %%
l = [10,20,30]
func1(*l)
# Out:
# (10, 20, (30,))

# %%
def func1(a,b,c):
    print(a, b, c)
func1(1,2,3)
# Out:
# 1 2 3

# %%
func1(1, c = 2, b = 3)
# Out:
# 1 3 2

# %%
def func1(a,b,*args):
    print(a,b,args)

# %%
func1(1,2,3,4)
# Out:
# 1 2 (3, 4)

# %%
def func1(a,b,*args,d):
    print(a,b,args,d)

# %%
func1(1,2,3,4,d=5)
# Out:
# 1 2 (3, 4) 5

# %%
def func1(*args,d):
    print(args,d)

# %%
func1(1,2,3,d='a')
# Out:
# (1, 2, 3) a

# %%
func1(d='a')
# Out:
# () a

# %% [markdown]
# * to stop positional arguments

# %%
def func1(*,d):
    print(d)

# %%
func1(30,d=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 func1(30,d=100)
#
# TypeError: func1() takes 0 positional arguments but 1 positional argument (and 1 keyword-only argument) were given

# %%
func1(d=100)
# Out:
# 100

# %%
def func(a,b,*,d):
    print(a,b,d)

# %%
func(1,2,d=4)
# Out:
# 1 2 4

# %%
def func(a,b=2,*args,d):
    print(a,b,args, d)

# %%
func(1,5,3,4,d='a')
# Out:
# 1 5 (3, 4) a

# %%
func(1,3,4,d='a')
# Out:
# 1 3 (4,) a

# %%
def func(a,b=2,*args,d=0, e):
    print(a,b,args, d, e)

# %%
func(1,5,3,4, d='a', e =5)
# Out:
# 1 5 (3, 4) a 5

# %%
func(1,b=5,3,4, d='a', e =5)
# Out:
#   Cell In[131], line 1
#     func(1,b=5,3,4, d='a', e =5)
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
func(1,5,3,4, d='unladen', e ='swallow')
# Out:
# 1 5 (3, 4) unladen swallow

# %% [markdown]
# **kwargs

# %%
def func(*args, **kwargs):
    print(args)
    print(kwargs)

# %%
func(a=1, b=2, c =3 )
# Out:
# ()
# {'a': 1, 'b': 2, 'c': 3}

# %%
func(1,2,3,a=1, b=2, c =3 )
# Out:
# (1, 2, 3)
# {'a': 1, 'b': 2, 'c': 3}

# %%
def func(a,b,*,**kwargs):
    print(a, b)
    print(kwargs)
# Out:
#   Cell In[8], line 1
#     def func(a,b,*,**kwargs):
#                    ^
# SyntaxError: named arguments must follow bare *

# %%
def func(a,b,*,d,**kwargs):
    print(a, b)
    print(kwargs)

# %%
func(1,2,d=1, e=2, c =3 )
# Out:
# 1 2
# {'e': 2, 'c': 3}

# %%
def func(a,b,**kwargs):
    print(a, b)
    print(kwargs)

# %%
func(1,2,x=100,y = 50 )
# Out:
# 1 2
# {'x': 100, 'y': 50}

# %%
def func(a,b=10,*args,d,**kwargs):
    print(a, b)
    print(kwargs)

# %%
func(1,2,d=100,y = 50 )
# Out:
# 1 2
# {'y': 50}

# %% [markdown]
# Recapping all

# %%
def func(a,b,*args):
    print(a,b,args)

# %%
func(1, 2, 'x', 'y', 'z')
# Out:
# 1 2 ('x', 'y', 'z')

# %%
func(a = 1, b = 2, 'x', 'y', 'z')
# Out:
#   Cell In[4], line 1
#     func(a = 1, b = 2, 'x', 'y', 'z')
#                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
def func(a,b=10,c=10,*args):
    print(a, b, c, args)

# %%
func(10,c=3,'x', 'y')
# Out:
#   Cell In[8], line 1
#     func(10,c=3,'x', 'y')
#                         ^
# SyntaxError: positional argument follows keyword argument

# %%
def func(a,b=10,*args,c=3,d):
    print(a, b, c, args, d)

# %%
func(10,20,'x', 'y', 'z', c=4, d =1)
# Out:
# 10 20 4 ('x', 'y', 'z') 1

# %%
func(10,'x', 'y', 'z', b=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 func(10,'x', 'y', 'z', b=4)
#
# TypeError: func() got multiple values for argument 'b'

# %%
func(10,'x', 'y', 'z', d=10)
# Out:
# 10 x 3 ('y', 'z') 10

# %%
def func(a, b, *args, c=10, d=20, **kwargs):
    print(a, b, args, c, d, kwargs)

# %%
func(1,2,'x','y','z',c=100,d=200,x=0.1,y=0.2)
# Out:
# 1 2 ('x', 'y', 'z') 100 200 {'x': 0.1, 'y': 0.2}

# %%
def calc_hi_lo_avg(*args, log_to_console = False):
    hi = int(bool(args)) and max(args)
    lo = int(bool(args)) and min(args)
    avg = (hi+lo)/2
    if log_to_console:
        print("high={0}, low={1}, avg={2}".format(hi,lo,avg))
    return avg

# %%
calc_hi_lo_avg(1,2,3,4,5,log_to_console = False)
# Out:
# 3.0

# %%
calc_hi_lo_avg(1,2,3,4,5,log_to_console = True)
# Out:
# high=5, low=1, avg=3.0
# 3.0

# %% [markdown]
# A simple Function Timer

# %%
import time
def time_it(fn,*args,**kwargs):
    print(args, kwargs)

# %%
time_it(print, 1, 2, 3, sep = ' - ', end = ' *** ' )
# Out:
# (1, 2, 3) {'sep': ' - ', 'end': ' *** '}

# %%
def time_it(fn,*args,rep=1,**kwargs):
    for i in range(rep):
        fn(*args, **kwargs)

# %%
time_it(print, 1, 2, 3, sep = ' - ', end = ' *** ' , rep = 5)
# Out:
# 1 - 2 - 3 *** 1 - 2 - 3 *** 1 - 2 - 3 *** 1 - 2 - 3 *** 1 - 2 - 3 ***

# %%
def time_it(fn,*args,rep=1,**kwargs):
    start  =time.perf_counter()
    for i in range(rep):
        fn(*args, **kwargs)
    end = time.perf_counter()
    return (end -start)/rep

# %%
time_it(print, 1, 2, 3, sep = ' - ', end = ' *** ' , rep = 5)
# Out:
# 1 - 2 - 3 *** 1 - 2 - 3 *** 1 - 2 - 3 *** 1 - 2 - 3 *** 1 - 2 - 3 ***
# 1.5800000073795673e-05

# %%
def computer_powers_1(n,*,start=1,end):
    results = []
    for i in range(start,end):
        results.append(n**i)
    return results

# %%
computer_powers_1(2, end = 5)
# Out:
# [2, 4, 8, 16]

# %%
def computer_powers_2(n,*,start=1,end):
    return [n**i for i in range(start, end)]
computer_powers_2(2, end = 5)
# Out:
# [2, 4, 8, 16]

# %%
def computer_powers_3(n,*,start=1,end):
    return (n**i for i in range(start, end))
computer_powers_3(2, end = 5)
# Out:
# <generator object computer_powers_3.<locals>.<genexpr> at 0x7a14a82407b0>

# %%
list(computer_powers_3(2, end = 5))
# Out:
# [2, 4, 8, 16]

# %%
time_it(computer_powers_3, 3, start = 1, rep = 5, end = 20000)
# Out:
# 9.557999874232336e-07

# %%
time_it(computer_powers_3, n = 3, start = 1, rep = 5, end = 20000)
# Out:
# 1.0739999197539873e-06

# %%
time_it(computer_powers_2, n = 3, start = 1, rep = 5, end = 20000)
# Out:
# 0.7044275452000874

# %%
def computer_powers_4(n,*,start=1,end):
    return list(n**i for i in range(start, end))
computer_powers_4(2, end = 5)
# Out:
# [2, 4, 8, 16]

# %%
time_it(computer_powers_4, n = 3, start = 1, rep = 5, end = 20000)
# Out:
# 0.7003924728000129

# %%
from datetime import datetime
datetime.utcnow()
# Out:
# datetime.datetime(2026, 1, 25, 14, 0, 44, 861427)

# %%
def log(msg,*,dt = datetime.utcnow()):
    print('{0}:{1}'.format(dt, msg))

# %%
log('message 1', dt = '2010-01-01 00:00:00.000')
# Out:
# 2010-01-01 00:00:00.000:message 1

# %%
log('message 1')
# Out:
# 2026-01-25 14:03:09.009469:message 1

# %%
log('message 2')#output is same because argument was calculated during function creation
# Out:
# 2026-01-25 14:03:09.009469:message 2

# %%
def log(msg,*,dt = None):
    dt = dt or datetime.utcnow()
    print('{0}:{1}'.format(dt, msg))

# %%
log('message 1')
# Out:
# 2026-01-25 14:06:03.625723:message 1

# %%
log('message 2')
# Out:
# 2026-01-25 14:06:12.579361:message 2

# %%
log('message 23', dt = '2010-01-01')
# Out:
# 2010-01-01:message 23

# %%
log('message 23', dt = None)
# Out:
# 2026-01-25 14:08:07.997153:message 23

# %%
log('message 23', dt = 0)
# Out:
# 2026-01-25 14:08:20.709620:message 23

# %%
log('message 23', dt = False)
# Out:
# 2026-01-25 14:08:29.997463:message 23

# %%
my_list = [1,2,3]

# %%
def func(a=my_list):
    print(a)

# %%
func(['a','b'])
# Out:
# ['a', 'b']

# %%
my_list.append(4)

# %%
func()
# Out:
# [1, 2, 3, 4]

# %%
my_tuple = (1,2,3)
def func(a=my_tuple):
    print(a)

# %%
func()
# Out:
# (1, 2, 3)

# %%
my_tuple.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 my_tuple.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# Parameters default beware 2

# %%
def add_item(name, quantity, unit, grocery_list):
    grocery_list.append('{0} ({1} {2})'.format(name, quantity, unit))
    return grocery_list

# %%
store1 = []
store2 = []

# %%
add_item('banana', 2, 'units', store1)
# Out:
# ['banana (2 units)']

# %%
add_item('milk', 1, 'liter', store1)
# Out:
# ['banana (2 units)', 'milk (1 liter)']

# %%
add_item('python', 1, 'medum-rare', store2)
# Out:
# ['python (1 medum-rare)']

# %%
del store1
del store2

# %%
def add_item(name, quantity, unit, grocery_list = []):
    grocery_list.append('{0} ({1} {2})'.format(name, quantity, unit))
    return grocery_list

# %%
store1 = add_item('milk', 1, 'liter')

# %%
add_item('banana', 2, 'units', store1)
# Out:
# ['milk (1 liter)', 'banana (2 units)']

# %%
store2 = add_item('python', 1, 'medum-rare')

# %%
store2
# Out:
# ['milk (1 liter)', 'banana (2 units)', 'python (1 medum-rare)']

# %%
store1 is store2
# Out:
# True

# %%
def add_item(name, quantity, unit=1, grocery_list = None):
    if not grocery_list:
        grocery_list = []
    grocery_list.append('{0} ({1} {2})'.format(name, quantity, unit))
    return grocery_list

# %%
store1 = add_item('milk', 1, 'liter')
add_item('banana', 2, 'units', store1)
store2 = add_item('python', 1, 'medum-rare')
store1 is store2
# Out:
# False

# %%
store1, store2
# Out:
# (['milk (1 liter)', 'banana (2 units)'], ['python (1 medum-rare)'])

# %%
def factorial(n):
    if n < 1:
        return 1
    else:
        print('calculating {0}!'.format(n))
        return n*factorial(n-1)

# %%
factorial(3)
# Out:
# calculating 3!
# calculating 2!
# calculating 1!
# 6

# %%
cache = {}
def factorial(n,*, cache):
    if n < 1:
        return 1
    elif n in cache:
        return cache[n]
    else:
        print('calculating {0}!'.format(n))
        result = n*factorial(n-1, cache = cache)
        cache[n] = result
        return result

# %%
factorial(3, cache = cache)
# Out:
# calculating 3!
# calculating 2!
# calculating 1!
# 6

# %%
factorial(6, cache = cache)
# Out:
# calculating 6!
# calculating 5!
# calculating 4!
# 720

# %%
def factorial(n,*, cache = {}):
    if n < 1:
        return 1
    elif n in cache:
        return cache[n]
    else:
        print('calculating {0}!'.format(n))
        result = n*factorial(n-1, cache = cache)
        cache[n] = result
        return result

# %%
factorial(3)
# Out:
# calculating 3!
# calculating 2!
# calculating 1!
# 6

# %%
factorial(6)
# Out:
# calculating 6!
# calculating 5!
# calculating 4!
# 720
