# %% [raw]
# Global and Local Scopes

# %%
a = 0
def my_func():
    global a 
    a = 100
    print(a)
print(a)
my_func()
# Out:
# 0
# 100

# %%
print(a)
# Out:
# 100

# %%
a = 10
def func():
    print(a)
    a = 100

# %%
func()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 func()
#
# Cell In[3], line 3, in func()
#       2 def func():
# ----> 3     print(a)
#       4     a = 100
#
# UnboundLocalError: local variable 'a' referenced before assignment

# %%
a = 10
def func():
    print(a)
func(), print(a)
# Out:
# 10
# 10
# (None, None)

# %%
a = 10
def func():
    global a
    a = 100
    print(a)
func(),print(a)
# Out:
# 100
# 100
# (None, None)

# %%
a = 10
print(a)
# Out:
# 10

# %%
def my_func(n):
    c = n**2
    return(c)

# %%
def my_func(n):
    print('global a:', a)
    c = a**n
    return c

# %%
my_func(2)
# Out:
# global a: 10
# 100

# %%
def my_func(n):
    a = 20
    c = a**n
    return c
print(a)
# Out:
# 10

# %%
my_func(2)
# Out:
# 400

# %%
print(a)
# Out:
# 10

# %%
def my_func(n):
    global a
    a = 20
    c = a**n
    return c

# %%
print(a)
# Out:
# 10

# %%
my_func(2)
# Out:
# 400

# %%
print(a)
# Out:
# 20

# %%
def my_func():
    global var
    var = 'hello world'
    return

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
my_func()
print(var)
# Out:
# hello world

# %%
a = 10
def my_func():
    global a
    a = 'hello'
    print('global a:', a)

# %%
my_func()
# Out:
# global a: hello

# %%
print(a)
# Out:
# hello

# %%
a = 10
def my_func():
    print('global a:', a)
    a = 'hello world'
    print(a)

# %%
print(a)
# Out:
# 10

# %%
my_func()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 my_func()
#
# Cell In[30], line 3, in my_func()
#       2 def my_func():
# ----> 3     print('global a:', a)
#       4     a = 'hello world'
#       5     print(a)
#
# UnboundLocalError: local variable 'a' referenced before assignment

# %%
a = 'abc'
def my_func():
    print(a)
    return a*10

# %%
print(a)
# Out:
# abc

# %%
my_func()
# Out:
# abc
# 'abcabcabcabcabcabcabcabcabcabc'

# %%
def print(x):
    return 'hello {0}'.format(x)

# %%
print('world')
# Out:
# 'hello world'

# %%
# since the print function got overriden we can del print to get back the orignal
del print

# %%
print('world')
# Out:
# world

# %% [markdown]
# for(int i = 0; i<10; i++) {
#     int x = 2*i;
# }
# system.out.println(x);

# %%
for i in range(10):
    x = 2*i

# %%
print(x)
# Out:
# 18

# %% [raw]
# Non local Scopes

# %%
def outer_func():
    x='hello'
    def inner_func():
        print(x)
    inner_func()

# %%
outer_func()
# Out:
# hello

# %%
def outer_func():
    x='hello'
    def inner1():
        def inner2():
            print(x)
        inner2()
    inner1()

# %%
outer_func()
# Out:
# hello

# %%
def outer_func():
    x='hello'
    def inner():
        x='python'
        print('inner',x)
    inner()
    print('outer', x)

# %%
outer_func()
# Out:
# inner python
# outer hello

# %%
def outer_func():
    x='hello'
    def inner():
        nonlocal x
        x='python'
        print('inner',x)
    print('outer(before)', x)
    inner()
    print('outer(after)', x)

# %%
outer_func()
# Out:
# outer(before) hello
# inner python
# outer(after) python

# %%
def outer():
    x='hello'
    def inner1():
        def inner2():
            nonlocal x
            x='python'
        inner2()
    inner1()
    print(x)

# %%
outer()
# Out:
# python

# %%
def outer():
    x='hello'
    def inner1():
        nonlocal x
        x='python'
        def inner2():
            nonlocal x
            x='monty'
        inner2()
    inner1()
    print(x)

# %%
outer()
# Out:
# monty

# %%
x = 'pyhton'

# %%
def outer():
    global x
    x='monty'
    def inner():
        nonlocal x
        x='hello'
    print(x)
# Out:
#   Cell In[73], line 5
#     nonlocal x
#     ^
# SyntaxError: no binding for nonlocal 'x' found

# %%
def outer():
    x='monty'
    def inner():
        nonlocal x
        x='hello'
    inner()
    print(x)

# %%
outer()
# Out:
# hello

# %%
print(x)
# Out:
# pyhton

# %% [markdown]
# Closures

# %%
def outer():
    x = 'python'
    def inner():
        print(x)
    print(x)
    return inner

# %%
fn = outer()
# Out:
# python

# %%
fn()
# Out:
# python

# %%
def outer():
    x = [1,2,3,4]
    def inner():
        #nonlocal x
        x.append(4)
        return x
    return inner

# %%
f1 = outer()
f2 = outer()

# %%
f1()
# Out:
# [1, 2, 3, 4, 4]

# %%
f1()
# Out:
# [1, 2, 3, 4, 4, 4]

# %%
f2()
# Out:
# [1, 2, 3, 4, 4]

# %%
f2()
# Out:
# [1, 2, 3, 4, 4, 4]

# %%
adders = []
f = lambda x: x + n
for n in range(4): 
    adders.append(f)
print(n)
print(adders)
print(adders[0](10))
print(adders[1](10))
print(adders[2](10))
print(adders[3](10))
# Out:
# 3
# [<function <lambda> at 0x703fb97148b0>, <function <lambda> at 0x703fb97148b0>, <function <lambda> at 0x703fb97148b0>, <function <lambda> at 0x703fb97148b0>]
# 13
# 13
# 13
# 13

# %%
adders
# Out:
# [<function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>]

# %%
adders2 = []
for n in range(4): 
    adders2.append(lambda : 10 + n)

# %%
print(adders2)
print(adders2[0]())
print(adders2[1]())
print(adders2[2]())
print(adders2[3]())
adders2[0]
# Out:
# [<function <lambda> at 0x703fb96d15e0>, <function <lambda> at 0x703fb9683040>, <function <lambda> at 0x703fb9683160>, <function <lambda> at 0x703fb9683670>]
# 13
# 13
# 13
# 13
# <function __main__.<lambda>()>

# %%
def my_func():
    adders = [] 
    for n in range(4): 
        adders.append(lambda x: x + n) 
    print("Free variables -> {0}, Closures -> {1}".format(adders[0].__code__.co_freevars, adders[0].__closure__))
 
my_func()
# Out:
# Free variables -> ('n',), Closures -> (<cell at 0x703fc8299a90: int object at 0x703fcfc91970>,)

# %%
def outer():
    x = 'python'
    def inner():
        print(x)
    return inner

# %%
fn = outer()

# %%
fn.__code__.co_freevars
# Out:
# ('x',)

# %%
fn.__closure__
# Out:
# (<cell at 0x79a45c067e50: str object at 0x79a45fe78d70>,)

# %%
def outer():
    x = [1,2,3]
    print(hex(id(x)))
    def inner():
        y = x
        print(hex(id(y)))
    return inner

# %%
fn = outer()
# Out:
# 0x79a4543bb8c0

# %%
fn.__closure__
# Out:
# (<cell at 0x79a454709ca0: list object at 0x79a4543bb8c0>,)

# %%
fn.__code__.co_freevars
# Out:
# ('x',)

# %%
def outer():
    count = 0
    def inc():
        nonlocal count
        count += 1
        return count
    return inc

# %%
f1 = outer()

# %%
f1.__code__.co_freevars
# Out:
# ('count',)

# %%
f1.__closure__
# Out:
# (<cell at 0x79a45c0676a0: int object at 0x79a46193d910>,)

# %%
f2 = outer()

# %%
f2.__code__.co_freevars
# Out:
# ('count',)

# %%
f2.__closure__
# Out:
# (<cell at 0x79a45c067b80: int object at 0x79a46193d910>,)

# %%
def outer():
    count = 0
    def inc1():
        nonlocal count
        count += 1
        return count
    def inc2():
        nonlocal count
        count += 1
        return count
    return inc1, inc2

# %%
f1, f2 = outer()

# %%
f1.__code__.co_freevars, f2.__code__.co_freevars
# Out:
# (('count',), ('count',))

# %%
f1.__closure__, f2.__closure__
# Out:
# ((<cell at 0x79a4546d15e0: int object at 0x79a46193d910>,),
#  (<cell at 0x79a4546d15e0: int object at 0x79a46193d910>,))

# %%
f1()
# Out:
# 1

# %%
f2()
# Out:
# 2

# %%
def pow(n):
    def inner(x):
        return x**n
    return inner

# %%
square = pow(2)

# %%
square.__closure__
# Out:
# (<cell at 0x79a45456ebe0: int object at 0x79a46193d950>,)

# %%
square(5)
# Out:
# 25

# %%
cube = pow(3)
cube.__closure__
# Out:
# (<cell at 0x79a4546dcfd0: int object at 0x79a46193d970>,)

# %%
def adder(n):
    def inner(x):
        return x + n
    return inner

# %%
add_1 = adder(1)
add_2 = adder(2)
add_3 = adder(3)

# %%
add_1(10)
# Out:
# 11

# %%
add_2(10)
# Out:
# 12

# %%
add_3(20)
# Out:
# 23

# %%
def create_adders():
    adders = []
    for n in range(1, 4):
        adders.append(lambda x, y=n : x+y)
    return adders

# %%
adders = create_adders()
adders[0].__closure__

# %%
adders[0](10), adders[1](10)# the bug of getting all same values is resolved by passing another parameter x that is equal to n
# since the parameters are calculated during fucntion definition we get the desired output
# Out:
# (11, 12)

# %% [markdown]
# Closures Applications(Part 1)

# %%
class Averager:
    def __init__(self):
        self.numbers = []
    def add(self, number):
        self.numbers.append(number)
        total = sum(self.numbers)
        count = len(self.numbers)
        return total/count

# %%
a = Averager()

# %%
a.add(10)
# Out:
# 10.0

# %%
a.add(20)
# Out:
# 15.0

# %%
a.add(30)
# Out:
# 20.0

# %%
b = Averager()

# %%
b.add(10)
# Out:
# 10.0

# %%
def Averager():
    numbers = []
    def add(number):
        numbers.append(number)
        total = sum(numbers)
        count = len(numbers)
        return total/count
    return add

# %%
a = Averager()

# %%
a(10)
# Out:
# 10.0

# %%
a(20)
# Out:
# 15.0

# %%
a(30)
# Out:
# 20.0

# %%
b= Averager()
b(10)
# Out:
# 10.0

# %%
def averager():
    total = 0
    count = 0
    def add(number):
        nonlocal total
        nonlocal count
        total = total + number
        count = count + 1
        return total/count
    return add

# %%
a= averager()

# %%
a.__closure__, a.__code__.co_freevars
# Out:
# ((<cell at 0x72c124466cd0: int object at 0x72c12d709910>,
#   <cell at 0x72c124484d30: int object at 0x72c12d709910>),
#  ('count', 'total'))

# %%
class Averager:
    def __init__(self):
        self.total = 0
        self.count = 0
    def add(self, number):
        total += number
        count += 1
        return self.total/self.count

# %%
from time import perf_counter

# %%
perf_counter()
# Out:
# 836.083196224

# %%
perf_counter()
# Out:
# 841.659654801

# %%
class Timer:
    def __init__(self):
        self.start = perf_counter()
    def __call__(self):
        return perf_counter() - self.start

# %%
t1 = Timer()

# %%
t1()
# Out:
# 0.19317260499997246

# %%
def timer():
    start = perf_counter()
    def poll():
        return perf_counter() - start
    return poll

# %%
t2 = Timer()
t2()
# Out:
# 1.7182999954457046e-05

# %%
t2()
# Out:
# 4.497278080000115

# %% [markdown]
# Closures Apllications (part 2)

# %%
def counter(initial_value=0):
    def inc(increment = 1):
        nonlocal initial_value
        initial_value += increment
        return initial_value
    return inc

# %%
counter1 = counter()

# %%
counter1()
# Out:
# 1

# %%
counter1()
# Out:
# 2

# %%
counter2 = counter()

# %%
counter2()
# Out:
# 1

# %%
def counter(fn):
    cnt = 0
    def inner(*args, **kwargs):
        nonlocal cnt
        cnt += 1
        print('{0} has been called {1} times'.format(fn.__name__, cnt))
        return fn(*args, **kwargs)
    return inner

# %%
def add(a, b):
    return a + b

# %%
def mult(a, b):
    return a * b

# %%
counter_add = counter(add)

# %%
counter_add(10, 20)
# Out:
# add has been called 1 times
# 30

# %%
counter_add(10, 20)
# Out:
# add has been called 2 times
# 30

# %%
counter_mult = counter(mult)

# %%
counter_mult(10, 20)
# Out:
# mult has been called 1 times
# 200

# %%
counter_mult(10, 20)
# Out:
# mult has been called 2 times
# 200

# %%
counters = dict()

# %%
def counter(fn):
    cnt = 0
    def inner(*args, **kwargs):
        nonlocal cnt
        cnt += 1
        counters[fn.__name__] = cnt
        return fn(*args, **kwargs)
    return inner

# %%
counter_add = counter(add)
counter_mult = counter(mult)

# %%
counter_add(10,20)
# Out:
# 30

# %%
counter_add(10,20)
# Out:
# 30

# %%
counter_mult(10, 20)
# Out:
# 200

# %%
counter_mult(10, 20)
# Out:
# 200

# %%
counters
# Out:
# {'add': 2, 'mult': 2}

# %%
def counter(fn, counters):
    cnt = 0
    def inner(*args, **kwargs):
        nonlocal cnt
        cnt += 1
        counters[fn.__name__] = cnt
        return fn(*args, **kwargs)
    return inner

# %%
c = dict()
counter_add = counter(add, c)
counter_mult = counter(mult, c)

# %%
counter_add(10,20)
# Out:
# 30

# %%
counter_add(10,20)
# Out:
# 30

# %%
counter_mult(10, 20)
# Out:
# 200

# %%
counter_mult(10, 20)
# Out:
# 200

# %%
c
# Out:
# {'add': 2, 'mult': 2}

# %%
def fact(n):
    product = 1
    for i in range(2, n+1):
        product *= i
    return product

# %%
fact(3)
# Out:
# 6

# %%
counter_fact = counter(fact, c)

# %%
counter_fact(5)
# Out:
# 120

# %%
c
# Out:
# {'add': 2, 'mult': 2, 'fact': 1}

# %%
fact = counter(fact, c)

# %%
fact(3)
# Out:
# 6

# %%
c
# Out:
# {'add': 2, 'mult': 2, 'fact': 1}

# %%
add = counter(add, c)

# %%
add(10,20)
# Out:
# 30

# %%
c
# Out:
# {'add': 1, 'mult': 2, 'fact': 1}

# %%
from functools import wraps
counters  = 0
def counter1(fn, counters):
    cnt = 0
    @wraps(fn)
    def inner(*args, **kwargs):
        nonlocal cnt
        global counters
        cnt += 1
        counters = cnt
        return fn(*args, **kwargs)
    print(inspect.signature(fn), fn.__name__)
    return inner

# %%
fact = counter1(fact, counters)
# Out:
# (*args, **kwargs) inner

# %%
fact(5)
# Out:
# 120

# %%
counters
# Out:
# 8

# %%
fact(13)
# Out:
# 6227020800

# %%
counters
# Out:
# 9

# %%
add.__name__
# Out:
# 'inner'

# %%
def divide(a, b):
    return a / b

# %%
fact = counter1(divide, counters)
# Out:
# (a, b) divide

# %%
divide.__name__
# Out:
# 'divide'

# %%
help(divide)
# Out:
# Help on function divide in module __main__:
#
# divide(a, b)

# %% [markdown]
# Decorators

# %%
def counter(fn):
    count = 0
    def inner(*args, **kwargs):
        nonlocal count
        count += 1
        print('Function {0} at id {2} was called {1} times'.format(fn.__name__, count, hex(id(fn))))
        return fn(*args, **kwargs)
    return inner

# %%
def add(a: int, b:int = 0):
    '''
    adds two values
    '''
    return a + b

# %%
help(add)
# Out:
# Help on function add in module __main__:
#
# add(a: int, b: int = 0)
#     adds two values

# %%
hex(id(add))
# Out:
# '0x7d847438a310'

# %%
add = counter(add)

# %%
add.__closure__
# Out:
# (<cell at 0x7d847c09ed90: int object at 0x7d848196c910>,
#  <cell at 0x7d847c10fbb0: function object at 0x7d847438a310>)

# %%
help(add)
# Out:
# Help on function inner in module __main__:
#
# inner(*args, **kwargs)

# %%
add(10, 20)
# Out:
# Function add at id 0x7d847438a310 was called 1 times
# 30

# %%
hex(id(add)) # the add id chenges because now it is refering to the inner function
# Out:
# '0x7d84743dd700'

# %%
def mult(a: int, b:int, c:int =1, *, d):
    '''
    multiplies values
    '''
    return a * b * c * d

# %%
mult(1,2 ,3, d =4)
# Out:
# 24

# %%
mult(1,2 , d =3)
# Out:
# 6

# %%
hex(id(mult))
# Out:
# '0x7d847438a280'

# %%
mult  = counter(mult)

# %%
help(mult)
# Out:
# Help on function inner in module __main__:
#
# inner(*args, **kwargs)

# %%
mult(1,2 ,3, d =4)
# Out:
# Function mult at id 0x7d847438a280 was called 1 times
# 24

# %%
mult(1,2 , d =3)
# Out:
# Function mult at id 0x7d847438a280 was called 2 times
# 6

# %%
@counter
def my_func(s: str, i: int) -> str:
    return s * i

# %%
help(my_func)
# Out:
# Help on function inner in module __main__:
#
# inner(*args, **kwargs)

# %%
my_func('a', 10)
# Out:
# Function my_func at id 0x7d847438a8b0 was called 1 times
# 'aaaaaaaaaa'

# %%
from functools import wraps

# %%
def counter(fn):
    count = 0
    def inner(*args, **kwargs):
        '''
        this is the inner closure
        '''
        nonlocal count
        count += 1
        print('Function {0} at id {2} was called {1} times'.format(fn.__name__, count, hex(id(fn))))
        return fn(*args, **kwargs)
    return inner

# %%
def mult(a: int, b:int, c:int =1, *, d):
    '''
    multiplies values
    '''
    return a * b * c * d

# %%
mult  = counter(mult)

# %%
help(mult)
# Out:
# Help on function inner in module __main__:
#
# inner(*args, **kwargs)
#     this is the inner closure

# %%
def counter(fn):
    count = 0
    @wraps(fn)
    def inner(*args, **kwargs):
        '''
        this is the inner closure
        '''
        nonlocal count
        count += 1
        print('Function {0} at id {2} was called {1} times'.format(fn.__name__, count, hex(id(fn))))
        return fn(*args, **kwargs)
    return inner

# %%
@counter
def mult(a: int, b:int, c:int =1, *, d):
    '''
    multiplies values
    '''
    return a * b * c * d

# %%
help(mult)
# Out:
# Help on function mult in module __main__:
#
# mult(a: int, b: int, c: int = 1, *, d)
#     multiplies values

# %%
mult = counter(mult)

# %%
help(mult)
# Out:
# Help on function mult in module __main__:
#
# mult(a: int, b: int, c: int = 1, *, d)
#     multiplies values

# %%
def counter(fn):
    count = 0
    def inner(*args, **kwargs):
        '''
        this is the inner closure
        '''
        nonlocal count
        count += 1
        print('Function {0} at id {2} was called {1} times'.format(fn.__name__, count, hex(id(fn))))
        return fn(*args, **kwargs)
    inner = wraps(fn)(inner)
    return inner

# %%
@counter
def add(a: int, b:int = 0):
    '''
    adds two values
    '''
    return a + b

# %%
add =counter(add)
help(add)
# Out:
# Help on function add in module __main__:
#
# add(a: int, b: int = 0)
#     adds two values

# %% [markdown]
# Decorator Application (Logger, Stacked Decorators)

# %%
def timed(fn):
    from time import perf_counter
    from functools import wraps
    @wraps(fn)
    def inner(*args, **kwargs):
        start = perf_counter()
        result = fn(*args, **kwargs)
        end = perf_counter()
        elapsed = end - start
        args_ = [str(a) for a in args]
        kwargs_ = ['{0}={1}'.format(k,v) for (k,v) in kwargs.items()]
        all_args = args_ + kwargs_
        args_str = ','.join(all_args)
        print('{0}({1}) took {2:.6f}s to run.'.format(fn.__name__, args_str, elapsed))
        return result
    return inner

# %% [markdown]
# Fibonacci : 1,1,2,3,5,8,13...

# %%
@timed
def calc_recursive_fib(n):
    if n <= 2:
        return 1
    else:
        return calc_recursive_fib(n-1) + calc_recursive_fib(n-2)

# %%
calc_recursive_fib(3)
# Out:
# calc_recursive_fib(2) took 0.000000s to run.
# calc_recursive_fib(1) took 0.000000s to run.
# calc_recursive_fib(3) took 0.000050s to run.
# 2

# %%
calc_recursive_fib(6)
# Out:
# calc_recursive_fib(2) took 0.000000s to run.
# calc_recursive_fib(1) took 0.000000s to run.
# calc_recursive_fib(3) took 0.000051s to run.
# calc_recursive_fib(2) took 0.000000s to run.
# calc_recursive_fib(4) took 0.000059s to run.
# calc_recursive_fib(2) took 0.000000s to run.
# calc_recursive_fib(1) took 0.000000s to run.
# calc_recursive_fib(3) took 0.000007s to run.
# calc_recursive_fib(5) took 0.000072s to run.
# calc_recursive_fib(2) took 0.000000s to run.
# calc_recursive_fib(1) took 0.000000s to run.
# calc_recursive_fib(3) took 0.000006s to run.
# calc_recursive_fib(2) took 0.000000s to run.
# calc_recursive_fib(4) took 0.000012s to run.
# calc_recursive_fib(6) took 0.000091s to run.
# 8

# %%
def calc_recursive_fib(n):
    if n <= 2:
        return 1
    else:
        return calc_recursive_fib(n-1) + calc_recursive_fib(n-2)

# %%
@timed
def fib_recursive(n):
    return calc_recursive_fib(n)

# %%
fib_recursive(6)
# Out:
# fib_recursive(6) took 0.000003s to run.
# 8

# %%
fib_recursive(30)
# Out:
# fib_recursive(30) took 0.078673s to run.
# 832040

# %%
fib_recursive(36)
# Out:
# fib_recursive(36) took 1.457258s to run.
# 14930352

# %%
@timed
def fib_loop(n):
    fib_1 = 1
    fib_2 = 1
    for i in range(3,n):
        fib_1, fib_2 = fib_2, fib_1 + fib_2
    return fib_2

# %%
fib_loop(6)
# Out:
# fib_loop(6) took 0.000002s to run.
# 5

# %%
from functools import reduce

# %% [markdown]
# n = 1
# (1,0) -> (1,1) result index[0]
# n = 2
# (1,0) -> (1,1) -> (2,1)
# result t[0] = 2
# n = 3
# (1,0) -> (1,1) -> (2,1) ->(3,2) result t[0] = 3

# %%
help(reduce)
# Out:
# Help on built-in function reduce in module _functools:
#
# reduce(...)
#     reduce(function, sequence[, initial]) -> value
#
#     Apply a function of two arguments cumulatively to the items of a sequence,
#     from left to right, so as to reduce the sequence to a single value.
#     For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates
#     ((((1+2)+3)+4)+5).  If initial is present, it is placed before the items
#     of the sequence in the calculation, and serves as a default when the
#     sequence is empty.

# %%
@timed
def fib_reduce(n):
    initial = (1,0)
    dummy = range(n)
    fib_n = reduce(lambda prev, n: (prev[0] + prev[1], prev[0]), dummy, initial)
    return fib_n[0]

# %%
fib_reduce(35)
# Out:
# fib_reduce(35) took 0.000006s to run.
# 14930352

# %%
fib_loop(5)
# Out:
# fib_loop(5) took 0.000002s to run.
# 3

# %%
def timed(fn):
    from time import perf_counter
    from functools import wraps
    @wraps(fn)
    def inner(*args, **kwargs):
        elapsed_total  = 0
        elapsed_count = 0
        for i in range(10):  
            print('running iteration {0}'.format(i))
            start = perf_counter()
            result = fn(*args, **kwargs)
            end = perf_counter()
            elapsed = end - start
            elapsed_total += elapsed
            elapsed_count += 1
        args_ = [str(a) for a in args]
        kwargs_ = ['{0}={1}'.format(k,v) for (k,v) in kwargs.items()]
        all_args = args_ + kwargs_
        args_str = ','.join(all_args)
        elapsed_avg = elapsed_total / elapsed_count
        print('{0}({1}) took {2:.6f}s to run.'.format(fn.__name__, args_str, elapsed_avg))
        return result
    return inner

# %%
@timed
def fib_reduce(n):
    initial = (1,0)
    dummy = range(n)
    fib_n = reduce(lambda prev, n: (prev[0] + prev[1], prev[0]), dummy, initial)
    return fib_n[0]

# %%
fib_reduce(100)
# Out:
# running iteration 0
# running iteration 1
# running iteration 2
# running iteration 3
# running iteration 4
# running iteration 5
# running iteration 6
# running iteration 7
# running iteration 8
# running iteration 9
# fib_reduce(100) took 0.000007s to run.
# 573147844013817084101

# %% [markdown]
# Decorator Application(Logger, Stacked Decorators)

# %%
def logged(fn):
    from functools import wraps
    from datetime import datetime, timezone
    @wraps(fn)
    def inner(*args, **kwargs):
        run_dt = datetime.now(timezone.utc)
        result = fn(*args, **kwargs)
        print('{0} called {1}'.format(run_dt, fn.__name__))
        return result
    return inner

# %%
@logged
def func_1():
    pass

# %%
@logged
def func_2():
    pass

# %%
func_1()
# Out:
# 2026-01-29 18:15:59.569715+00:00 called func_1

# %%
func_2()
# Out:
# 2026-01-29 18:16:00.274612+00:00 called func_2

# %%
@logged
@timed
def fact(n):
    result = reduce(lambda a, b: a*b, range(1,n+1))
    return result

# %%
def fact(n):
    result = reduce(lambda a, b: a*b, range(1,n+1))
    return result

# %%
logged(timed(fact))(20)
# Out:
# running iteration 0
# running iteration 1
# running iteration 2
# running iteration 3
# running iteration 4
# running iteration 5
# running iteration 6
# running iteration 7
# running iteration 8
# running iteration 9
# fact(20) took 0.000001s to run.
# 2026-01-29 18:22:28.169225+00:00 called fact
# 2432902008176640000

# %%
fact(3)
# Out:
# running iteration 0
# running iteration 1
# running iteration 2
# running iteration 3
# running iteration 4
# running iteration 5
# running iteration 6
# running iteration 7
# running iteration 8
# running iteration 9
# fact(3) took 0.000001s to run.
# 2026-01-28 14:14:05.865637+00:00 called fact
# 6

# %%
def dec_1(fn):
    def inner():
        print('Running dec_1')
        return fn()
    return inner

# %%
def dec_2(fn):
    def inner():
        print('Running dec_2')
        return fn()
    return inner

# %%
@dec_1
@dec_2
def my_func():
    print('Running my_func')

# %%
my_func()
# Out:
# Running dec_1
# Running dec_2
# Running my_func

# %%
def dec_1_(fn):
    def inner():
        result = fn()
        print('Running dec_1')
        return result
    return inner

# %%
def dec_2_(fn):
    def inner():
        result = fn()
        print('Running dec_2')
        return result
    return inner

# %%
@dec_1_
@dec_2_
@logged
@timed
def my_func_():
    print('Running my_func')

# %%
my_func_()
# Out:
# running iteration 0
# Running my_func
# running iteration 1
# Running my_func
# running iteration 2
# Running my_func
# running iteration 3
# Running my_func
# running iteration 4
# Running my_func
# running iteration 5
# Running my_func
# running iteration 6
# Running my_func
# running iteration 7
# Running my_func
# running iteration 8
# Running my_func
# running iteration 9
# Running my_func
# my_func_() took 0.000002s to run.
# 2026-01-28 14:52:08.296091+00:00 called my_func_
# Running dec_2
# Running dec_1

# %% [markdown]
# @auth
# @logged
# def save_resource():
#     pass
# the order in which you pass decorators matters, as you want to authorize first and only then log

# %% [markdown]
# Decorator Applications (Memoization)

# %%
def fib(n):
    print('Calculating fib({0})'.format(n))
    return 1 if n < 3 else fib(n-1) + fib(n-2)

# %%
class Fib:
    def __init__(self):
        self.cache = {1:1, 2:1}
    def fib(self, n):
        if n not in self.cache:
            print('calculating fib({0})'.format(n))
            self.cache[n] = self.fib(n-1) + self.fib(n-2)
        return self.cache[n]

# %%
f = Fib()

# %%
f.fib(5)
# Out:
# calculating fib(5)
# calculating fib(4)
# calculating fib(3)
# 5

# %%
f.fib(6)
# Out:
# calculating fib(6)
# 8

# %%
f.fib(10)
# Out:
# calculating fib(10)
# calculating fib(9)
# calculating fib(8)
# calculating fib(7)
# 55

# %%
def fib():
    cache = {1:1, 2:1}
    def calc_fib(n):
        if n not in cache:
            print('calculating fib({0})'.format(n))
            cache[n] = calc_fib(n-1)+calc_fib(n-2)
        return cache[n]
    return calc_fib

# %%
f = fib()

# %%
f(10)
# Out:
# calculating fib(10)
# calculating fib(9)
# calculating fib(8)
# calculating fib(7)
# calculating fib(6)
# calculating fib(5)
# calculating fib(4)
# calculating fib(3)
# 55

# %%
f(50)
# Out:
# calculating fib(50)
# calculating fib(49)
# calculating fib(48)
# calculating fib(47)
# calculating fib(46)
# calculating fib(45)
# calculating fib(44)
# calculating fib(43)
# calculating fib(42)
# calculating fib(41)
# calculating fib(40)
# calculating fib(39)
# calculating fib(38)
# calculating fib(37)
# calculating fib(36)
# calculating fib(35)
# calculating fib(34)
# calculating fib(33)
# calculating fib(32)
# calculating fib(31)
# calculating fib(30)
# calculating fib(29)
# calculating fib(28)
# calculating fib(27)
# calculating fib(26)
# calculating fib(25)
# calculating fib(24)
# calculating fib(23)
# calculating fib(22)
# calculating fib(21)
# calculating fib(20)
# calculating fib(19)
# calculating fib(18)
# calculating fib(17)
# calculating fib(16)
# calculating fib(15)
# calculating fib(14)
# calculating fib(13)
# calculating fib(12)
# calculating fib(11)
# 12586269025

# %%
def memoize_fib(fib):
    cache = {1:1, 2:1}
    def inner(n):
        if n not in cache:
            #print('calculating fib({0})'.format(n))
            cache[n] = fib(n)
        return cache[n]
    return inner

# %%
@memoize_fib
def fib(n):
    print('Calculating fib({0})'.format(n))
    return 1 if n < 3 else fib(n-1) + fib(n-2)

# %%
fib(10)
# Out:
# Calculating fib(10)
# Calculating fib(9)
# Calculating fib(8)
# Calculating fib(7)
# Calculating fib(6)
# Calculating fib(5)
# Calculating fib(4)
# Calculating fib(3)
# 55

# %%
fib(13)
# Out:
# Calculating fib(13)
# Calculating fib(12)
# Calculating fib(11)
# 233

# %%
def memoize_fib_emptycache(fn):
    cache = dict()
    def inner(n):
        if n not in cache:
            #print('calculating fib({0})'.format(n))
            cache[n] = fn(n)
        return cache[n]
    return inner

# %%
@memoize_fib_emptycache
def fib_(n):
    print('Calculating fib({0})'.format(n))
    return 1 if n < 3 else fib_(n-1) + fib_(n-2)

# %%
fib_(2)
# Out:
# Calculating fib(2)
# 1

# %%
fib_(3)
# Out:
# Calculating fib(3)
# Calculating fib(1)
# 2

# %%
fib_(10)
# Out:
# Calculating fib(10)
# Calculating fib(9)
# Calculating fib(8)
# Calculating fib(7)
# Calculating fib(6)
# Calculating fib(5)
# Calculating fib(4)
# 55

# %%
@memoize_fib_emptycache
def fact_(n):
    print('calculating {0}!'.format(n))
    return 1 if n < 2 else n * fact_(n-1)

# %%
fact_(6)
# Out:
# calculating 6!
# calculating 5!
# calculating 4!
# calculating 3!
# calculating 2!
# calculating 1!
# 720

# %%
fact_(10)
# Out:
# calculating 10!
# calculating 9!
# calculating 8!
# calculating 7!
# 3628800

# %%
from functools import lru_cache

# %%
@lru_cache()
def fib(n):
    print('Calculating fib({0})'.format(n))
    return 1 if n < 3 else fib(n-1) + fib(n-2)

# %%
fib(131)
# Out:
# Calculating fib(131)
# Calculating fib(130)
# Calculating fib(129)
# Calculating fib(128)
# Calculating fib(127)
# Calculating fib(126)
# Calculating fib(125)
# Calculating fib(124)
# Calculating fib(123)
# Calculating fib(122)
# Calculating fib(121)
# Calculating fib(120)
# Calculating fib(119)
# Calculating fib(118)
# Calculating fib(117)
# Calculating fib(116)
# Calculating fib(115)
# Calculating fib(114)
# Calculating fib(113)
# Calculating fib(112)
# Calculating fib(111)
# Calculating fib(110)
# Calculating fib(109)
# Calculating fib(108)
# Calculating fib(107)
# Calculating fib(106)
# Calculating fib(105)
# Calculating fib(104)
# Calculating fib(103)
# Calculating fib(102)
# Calculating fib(101)
# Calculating fib(100)
# Calculating fib(99)
# Calculating fib(98)
# Calculating fib(97)
# Calculating fib(96)
# Calculating fib(95)
# Calculating fib(94)
# Calculating fib(93)
# Calculating fib(92)
# Calculating fib(91)
# Calculating fib(90)
# Calculating fib(89)
# Calculating fib(88)
# ...

# %%
fib(3)
# Out:
# Calculating fib(3)
# Calculating fib(2)
# Calculating fib(1)
# 2

# %%
@lru_cache(maxsize = 8)
def fib(n):
    print('Calculating fib({0})'.format(n))
    return 1 if n < 3 else fib(n-1) + fib(n-2)

# %%
fib(8)
# Out:
# Calculating fib(8)
# Calculating fib(7)
# Calculating fib(6)
# Calculating fib(5)
# Calculating fib(4)
# Calculating fib(3)
# Calculating fib(2)
# Calculating fib(1)
# 21

# %%
fib(8)
# Out:
# 21

# %%
fib(9)
# Out:
# Calculating fib(9)
# 34

# %%
fib(16)
# Out:
# Calculating fib(16)
# Calculating fib(15)
# Calculating fib(14)
# Calculating fib(13)
# Calculating fib(12)
# Calculating fib(11)
# Calculating fib(10)
# Calculating fib(9)
# 987

# %%
fib(1)
# Out:
# Calculating fib(1)
# 1

# %%
fib(8)
# Out:
# Calculating fib(8)
# Calculating fib(7)
# Calculating fib(6)
# Calculating fib(5)
# Calculating fib(4)
# Calculating fib(3)
# Calculating fib(2)
# 21

# %%
fib(16)
# Out:
# Calculating fib(16)
# Calculating fib(15)
# Calculating fib(14)
# Calculating fib(13)
# Calculating fib(12)
# Calculating fib(11)
# Calculating fib(10)
# Calculating fib(9)
# 987

# %%
fib(8)
# Out:
# Calculating fib(8)
# Calculating fib(7)
# Calculating fib(6)
# Calculating fib(5)
# Calculating fib(4)
# Calculating fib(3)
# Calculating fib(2)
# Calculating fib(1)
# 21

# %%
print(list(fib.cache_parameters().items()))
# Out:
# [('maxsize', 128), ('typed', False)]

# %%
@lru_cache(maxsize = 8)
def fib(n):
    print('Calculating fib({0})'.format(n))
    return 1 if n < 3 else fib(n-1) + fib(n-2)

# %%
fib(8)
# Out:
# Calculating fib(8)
# Calculating fib(7)
# Calculating fib(6)
# Calculating fib(5)
# Calculating fib(4)
# Calculating fib(3)
# Calculating fib(2)
# Calculating fib(1)
# 21

# %%
print(fib.cache_info())
# Out:
# CacheInfo(hits=5, misses=8, maxsize=8, currsize=8)

# %% [markdown]
# Decorators factory

# %%
def timed(fn):
    from time import perf_counter
    def inner(*args, **kwargs):
        start = perf_counter()
        result = fn(*args, **kwargs)
        end = perf_counter()
        elapsed = end- start
        print('Run time: {0:.6f}s'.format(elapsed))
        return result
    return inner

# %%
def calc_fib_recurse(n):
    return 1 if n < 3 else calc_fib_recurse(n-2) + calc_fib_recurse(n-1)
def fib(n):
    return calc_fib_recurse(n)

# %%
fib(20)
# Out:
# 6765

# %%
fib = timed(fib)

# %%
fib(30)
# Out:
# Run time: 0.082650s
# 832040

# %%
def timed(fn):
    from time import perf_counter
    def inner(*args, **kwargs):
        total_elapsed = 0
        for i in range(10):
            start = perf_counter()
            result = fn(*args, **kwargs)
            end = perf_counter()
            total_elapsed = end- start
        avg_run_time = total_elapsed / 10
        print('Run time: {0:.6f}s'.format(avg_run_time))
        return result
    return inner

# %%
def fib(n):
    return calc_fib_recurse(n)

# %%
fib = timed(fib)

# %%
fib(28)
# Out:
# Run time: 0.003240s
# 317811

# %%
def timed(reps):
    def dec(fn):
        from time import perf_counter
        def inner(*args, **kwargs):
            total_elapsed = 0
            for i in range(reps):
                start = perf_counter()
                result = fn(*args, **kwargs)
                end = perf_counter()
                total_elapsed = end- start
            avg_run_time = total_elapsed / 10
            print('Run time: {0:.6f}s ({1} reps)'.format(avg_run_time, reps))
            return result
        return inner
    return dec

# %%
@timed(10)
def fib(n):
    return calc_fib_recurse(n)

# %%
fib(28)
# Out:
# Run time: 0.003156s (10 reps)
# 317811

# %%
def dec(fn):
    print('running dec')
    def inner(*args, **kwargs):
        print('running inner')
        return fn(*args, **kwargs)
    return inner

# %%
@dec
def my_func():
    print('running my_func')
# Out:
# running dec

# %%
my_func()
# Out:
# running inner
# running my_func

# %%
def dec_factory():
    print('running dec factory')
    def dec(fn):
        print('running dec')
        def inner(*args, **kwargs):
            print('running inner')
            return fn(*args, **kwargs)
        return inner
    return dec

# %%
def my_func():
    print('running my_func')

# %%
dec = dec_factory()
# Out:
# running dec factory

# %%
my_func = dec(my_func)
# Out:
# running dec

# %%
my_func()
# Out:
# running inner
# running my_func

# %%
@dec
def my_func():
    print('running my_func')
# Out:
# running dec

# %%
my_func()
# Out:
# running inner
# running my_func

# %%
@dec_factory()
def my_func():
    print('running my_func')
# Out:
# running dec factory
# running dec

# %%
def dec_factory(a,b):
    print('running dec factory')
    def dec(fn):
        print('running dec')
        def inner(*args, **kwargs):
            print('running inner')
            print('a={0}, b = {1}'.format(a, b))
            return fn(*args, **kwargs)
        return inner
    return dec

# %%
dec = dec_factory(10, 20)
# Out:
# running dec factory

# %%
@dec
def my_func():
    print('running my_func')
# Out:
# running dec

# %%
my_func()
# Out:
# running inner
# a=10, b = 20
# running my_func

# %%
@dec_factory(10, 20)
def my_func():
    print('running my_func')
# Out:
# running dec factory
# running dec

# %%
my_func()
# Out:
# running inner
# a=10, b = 20
# running my_func

# %%
def my_func():
    print('running my_func')

# %%
my_func = dec_factory(10, 20)(my_func)
# Out:
# running dec factory
# running dec

# %%
my_func()
# Out:
# running inner
# a=10, b = 20
# running my_func

# %% [markdown]
# Decorator Application - Decorator Class

# %%
def my_dec(a,b):
    def dec(fn):
        def inner(*args, **kwargs):
            print('decorated function called a={0}, b ={1}'.format(a,b))
            return fn(*args, **kwargs)
        return inner
    return dec

# %%
@my_dec(10,20)
def my_func(s):
    print('Hello {0}'.format(s))

# %%
my_func('World')
# Out:
# decorated function called a=10, b =20
# Hello World

# %%
class MyClass:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def __call__(self, c):
        print('called a = {0}, b ={1}, c={2}'.format(self.a, self.b, c))

# %%
obj = MyClass(10, 20)

# %%
obj(10)
# Out:
# called a = 10, b =20, c=10

# %%
class MyClass:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def __call__(self, fn):
        def inner(*args, **kwargs):
            print('decorated function called a={0}, b ={1}'.format(self.a,self.b))
            return fn(*args, **kwargs)
        return inner

# %%
@MyClass(10, 20)
def my_func(s):
    print('Hello {0}'.format(s))

# %%
my_func('world')
# Out:
# decorated function called a=10, b =20
# Hello world

# %%
obj = MyClass(10, 20)

# %%
def my_func(s):
    print('Hello {0}'.format(s))

# %%
my_func = obj(my_func)

# %%
my_func('world')
# Out:
# decorated function called a=10, b =20
# Hello world

# %% [markdown]
# Decorating Classes

# %%
from fractions import Fraction

# %%
f = Fraction(2,3)

# %%
f.denominator
# Out:
# 3

# %%
f.numerator
# Out:
# 2

# %%
f.speak()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[425], line 1
# ----> 1 f.speak()
#
# AttributeError: 'Fraction' object has no attribute 'speak'

# %%
Fraction.speak = 100

# %%
f.speak
# Out:
# 100

# %%
Fraction.speak = lambda self, message: 'Fraction says: {0}'.format(message)

# %%
f.speak('This is a late parrot')
# Out:
# 'Fraction says: This is a late parrot'

# %%
f.speak('This parrot is no more')
# Out:
# 'Fraction says: This parrot is no more'

# %%
Fraction.is_integral = lambda self: self.denominator == 1

# %%
f1 = Fraction(2,3)
f2 = Fraction(64,8)

# %%
f1
# Out:
# Fraction(2, 3)

# %%
f2
# Out:
# Fraction(8, 1)

# %%
f1.is_integral()
# Out:
# False

# %%
f2.is_integral()
# Out:
# True

# %%
def dec_speak(cls):
    cls.speak = lambda self, message: '{0} says {1}'.format(self.__class__.__name__,message)
    return cls

# %%
Fraction = dec_speak(Fraction)

# %%
f1 = Fraction(2,3)

# %%
f1.speak('hello')
# Out:
# 'Fraction says hello'

# %%
from datetime import datetime, timezone

# %%
def debug_info(cls):
    def info(self):
        results = []
        results.append('time {0}'.format(datetime.now(timezone.utc)))
        results.append('Class {0}'.format(self.__class__,__name__))
        results.append('id {0}'.format(hex(id(self))))
        for k, v in vars(self).items():
            results.append('{0}: {1}'.format(k, v))
        return results  
    cls.debug = info

# %%
def info(self):
    results = []
    results.append('time {0}'.format(datetime.now(timezone.utc)))
    results.append('Class {0}'.format(self.__class__,__name__))
    results.append('id {0}'.format(hex(id(self))))
    for k, v in vars(self).items():
        results.append('{0}: {1}'.format(k, v))
    return results
    
def debug_info(cls):
    cls.debug = info
    return cls

# %%
@debug_info
class Person:
    def __init__(self, name, birth_year):
        self.name = name
        self.birth_year = birth_year
    def say_hi():
        return 'hello there!'

# %%
p = Person('John', 1939)

# %%
p.debug()
# Out:
# ['time 2026-01-29 08:43:34.290403+00:00',
#  "Class <class '__main__.Person'>",
#  'id 0x7c1bc832da00',
#  'name: John',
#  'birth_year: 1939']

# %%
@debug_info
class Automobile:
    def __init__(self, make, model, year, top_speed):
        self.make = make
        self.model = model
        self.year = year
        self.top_speed = top_speed
        self._speed = 0
    @property
    def speed(self):
        return self.speed
    @speed.setter
    def speed(self, new_speed):
        if new_speed > self.top_speed:
            raise ValueError('speed cannot exceed top speed')
        else:
            self._speed = new_speed

# %%
favorites  = Automobile('Ford', 'Model T', 1908, 45)

# %%
favorites.debug()
# Out:
# ['time 2026-01-29 11:04:28.298084+00:00',
#  "Class <class '__main__.Automobile'>",
#  'id 0x7c1bc84647c0',
#  'make: Ford',
#  'model: Model T',
#  'year: 1908',
#  'top_speed: 45',
#  '_speed: 0']

# %%
favorites.speed = 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 favorites.speed = 100
#
# Cell In[34], line 15, in Automobile.speed(self, new_speed)
#      12 @speed.setter
#      13 def speed(self, new_speed):
#      14     if new_speed > self.top_speed:
# ---> 15         raise ValueError('speed cannot exceed top speed')
#      16     else:
#      17         self._speed = new_speed
#
# ValueError: speed cannot exceed top speed

# %%
favorites.speed = 40

# %%
from math import sqrt

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)

# %%
p1, p2, p3 = Point(2, 3), Point(2, 3), Point(0, 8)

# %%
abs(p1)
# Out:
# 3.605551275463989

# %%
p1
# Out:
# Point(2, 3)

# %%
p1 is p2
# Out:
# False

# %%
p1 == p2 # this is weird, but this happens because we don't have an equal method in our class
# Out:
# False

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)
    def __eq__(self, other):
        if isinstance(other, Point):
            return self.x == other.x and self.y == other.y
        else:
            return False
    def __lt__(self, other):
        if isinstance(other, Point):
            return abs(self) < abs(other)
        else:
            return NotImplemented

# %%
p1, p2, p3 = Point(2, 3), Point(2, 3), Point(0, 8)

# %%
p1 == p2
# Out:
# True

# %%
p3 < p1
# Out:
# False

# %%
p4 = Point(100,100)

# %%
p4 < p1
# Out:
# False

# %%
p4 > p1 # works because even though greater than is not defined less tahn is and python can do the reverse of it
# Out:
# True

# %%
p4 >= p1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 p4 >= p1
#
# TypeError: '>=' not supported between instances of 'Point' and 'Point'

# %%
def complete_ordering(cls):
    if '__eq__' in dir(cls) and '__lt__' in dir(cls):
        cls.__le__ = lambda self, other:  self < other or self == other
        cls.__gt__ = lambda self, other:  not(self < other) and not (self == other)
        cls.__ge__ = lambda self, other:  not(self < other)
    return cls

# %%
@complete_ordering
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)
    def __eq__(self, other):
        if isinstance(other, Point):
            return self.x == other.x and self.y == other.y
        else:
            return False
    def __lt__(self, other):
        if isinstance(other, Point):
            return abs(self) < abs(other)
        else:
            return NotImplemented

# %%
p1, p2, p3, p4 = Point(2, 3), Point(2, 3), Point(0, 8), Point(100,100)

# %%
p1 >= p3
# Out:
# False

# %%
from functools import total_ordering

# %%
@total_ordering
@debug_info
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)
    def __eq__(self, other):
        if isinstance(other, Point):
            return self.x == other.x and self.y == other.y
        else:
            return False
    def __lt__(self, other):
        if isinstance(other, Point):
            return abs(self) < abs(other)
        else:
            return NotImplemented

# %%
p1, p2, p3, p4 = Point(2, 3), Point(2, 3), Point(0, 8), Point(100,100)

# %%
p1 >= p3
# Out:
# False

# %%
p1.debug()
# Out:
# ['time 2026-01-29 12:03:10.083126+00:00',
#  "Class <class '__main__.Point'>",
#  'id 0x7c1bc83239a0',
#  'x: 2',
#  'y: 3']

# %%
@total_ordering
@debug_info
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)
    def __eq__(self, other):
        if isinstance(other, Point):
            return self.x == other.x and self.y == other.y
        else:
            return False
    def __gt__(self, other):
        if isinstance(other, Point):
            return abs(self) > abs(other)
        else:
            return NotImplemented

# %%
p1, p2, p3, p4 = Point(2, 3), Point(2, 3), Point(0, 8), Point(100,100)

# %%
p1 < p4
# Out:
# True

# %%
@total_ordering
@debug_info
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)
    def __gt__(self, other):
        if isinstance(other, Point):
            return abs(self) > abs(other)
        else:
            return NotImplemented

# %%
p1, p2, p3, p4 = Point(2, 3), Point(2, 3), Point(0, 8), Point(100,100)

# %%
p1 == p4
# Out:
# False

# %%
p1 < p4
# Out:
# True

# %%
@total_ordering
@debug_info
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __abs__(self):
        return sqrt(self.x**2 + self.y ** 2)
    def __repr__(self):
        return 'Point({0}, {1})'.format(self.x, self.y)
    def __eq__(self, other):
        if isinstance(other, Point):
            return self.x == other.x and self.y == other.y
        else:
            return False
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 3
#       1 @total_ordering
#       2 @debug_info
# ----> 3 class Point:
#       4     def __init__(self, x, y):
#       5         self.x = x
#
# File ~/miniconda3/envs/tf2.11/lib/python3.9/functools.py:193, in total_ordering(cls)
#     191 roots = {op for op in _convert if getattr(cls, op, None) is not getattr(object, op, None)}
#     192 if not roots:
# --> 193     raise ValueError('must define at least one ordering operation: < > <= >=')
#     194 root = max(roots)       # prefer __lt__ to __le__ to __gt__ to __ge__
#     195 for opname, opfunc in _convert[root]:
#
# ValueError: must define at least one ordering operation: < > <= >=

# %% [markdown]
# Decorator Application: Single Dispath Generic Functions

# %%
from html import escape

# %%
def html_escape(arg):
    return escape(str(arg))
def html_int(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))
def html_real(a):
    return '{0:.2f}'.format(round(a, 2))
def html_str(s):
    return html_escape(s).replace('\n', '<br/>\n')
def html_list(l):
    items = ('<li>{0}</li>'.format(htmlize(item)) for item in l)
    return '<ul>\n' + '\n'.join(items) + '\n</ul>'
def html_dict(d):
    items = ('<li>{0}={1}</li>'.format(html_escape(k), htmlize(v)) for k, v in dict.items())
    return '<ul>\n' + '\n'.join(items) + '\n</ul>'
def html_set(arg):
    return html_list(arg)

# %%
print(html_str('''This is a multi line
string with special characters: 10 < 100'''))
# Out:
# This is a multi line<br/>
# string with special characters: 10 &lt; 100

# %%
print(html_int(255))
# Out:
# 255(<i>0xff</i>)

# %%
print(html_escape(3+10j))
# Out:
# (3+10j)

# %%
from decimal import Decimal

# %%
def htmlize(arg):
    if isinstance(arg, int):
        return html_int(arg)
    elif isinstance(arg, float) or isinstance(arg, Decimal):
        return html_real(arg)
    elif isinstance(arg, str):
        return html_str(arg)
    elif isinstance(arg, list) or isinstance(arg, tuple):
        return html_list(arg)
    elif isinstance(arg, dict):
        return html_dict(arg)
    elif isinstance(arg, set):
        return html_set(arg)
    else:
        return html_escape(arg)

# %%
htmlize(100)
# Out:
# '100(<i>0x64</i>)'

# %%
htmlize('''python 
rocks!
''')
# Out:
# 'python <br/>\nrocks!<br/>\n'

# %%
print(htmlize([1,2,3]))
# Out:
# <ul>
# <li>1(<i>0x1</i>)</li>
# <li>2(<i>0x2</i>)</li>
# <li>3(<i>0x3</i>)</li>
# </ul>

# %%
print(htmlize(['''Python rocks! 0 < 1''', (10, 20, 30), 100]))
# Out:
# <ul>
# <li>Python rocks! 0 &lt; 1</li>
# <li><ul>
# <li>10(<i>0xa</i>)</li>
# <li>20(<i>0x14</i>)</li>
# <li>30(<i>0x1e</i>)</li>
# </ul></li>
# <li>100(<i>0x64</i>)</li>
# </ul>

# %%
htmlize({1,2,3})
# Out:
# '<ul>\n<li>1(<i>0x1</i>)</li>\n<li>2(<i>0x2</i>)</li>\n<li>3(<i>0x3</i>)</li>\n</ul>'

# %%
def htmlize(arg):
    registry = {
        object: html_escape,
        int: html_int,
        float: html_int,
        Decimal: html_int,
        str: html_str,
        list: html_list,
        tuple: html_list,
        set: html_set,
        dict: html_dict
        }
    fn = registry.get(type(arg), registry[object])
    return fn(arg)

# %%
htmlize(100)
# Out:
# '100(<i>0x64</i>)'

# %%
print(htmlize([1,2,3]))
# Out:
# <ul>
# <li>1(<i>0x1</i>)</li>
# <li>2(<i>0x2</i>)</li>
# <li>3(<i>0x3</i>)</li>
# </ul>

# %%
# Our decorator 
def list_decorator(func): 
    def wrapper(*args, **kwargs): 
        result = func(*args, **kwargs) # call the original function 
        if isinstance(result, list): # ensure it's a list 
            return [x * 2 for x in result] # modify the list 
        return result 
    return wrapper # A sample function that returns a list @list_decorator 
def get_numbers(): 
    return [1, 2, 3, 4] 
print(get_numbers())
# Out:
# [1, 2, 3, 4]

# %%
def add_elements(list, *args):
    print(list)
    return list

# %%
@add_elements 
def get_numbers(): return [1, 2, 3]
# Out:
# <function get_numbers at 0x7c1bb8c780d0>

# %%
get_numbers = add_elements(get_numbers)
# Out:
# <function get_numbers at 0x7c1bb8c780d0>

# %%
get_numbers()
# Out:
# [1, 2, 3]

# %%
def singledispatch(fn):
    registry = {}
    registry[object] = fn
    registry[int] = lambda a : '{0}(<i>{1}</i>)'.format(a, str(hex(a)))
    registry[str] = lambda s: escape(s).replace('\n', '<br/>\n')
    def inner(arg):
        f = registry.get(type(arg), registry[object])
        return registry[object](arg)
    return inner

# %%
@singledispatch
def htmlize(a):
    return escape(str(a))

# %%
htmlize('1<100')
# Out:
# '1&lt;100'

# %%
htmlize(100)
# Out:
# '100'

# %%
def singledispatch(fn):
    registry = {}
    registry[object] = fn
    def decorated(arg):
        return registry.get(type(arg), registry[object])(arg)
    def register(type_):
        def inner(fn):
            registry[type_] = fn
            return fn
        return inner
    def dispatch(type_):
        return registry.get(type_, registry[object])
    decorated.register = register  
    #decorated.registry = registry
    decorated.dispatch = dispatch
    return decorated

# %%
@singledispatch
def htmlize(a):
    return escape(str(a))

# %%
singledispatch(htmlize)
# Out:
# <function __main__.singledispatch.<locals>.decorated(arg)>

# %%
htmlize('1<100')
# Out:
# '1&lt;100'

# %%
htmlize.register
# Out:
# <function __main__.singledispatch.<locals>.register(type_)>

# %%
@htmlize.register(int)
def html_int(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))

# %%
html_int
# Out:
# <function __main__.html_int(a)>

# %%
htmlize(100)
# Out:
# '100(<i>0x64</i>)'

# %%
@htmlize.register(tuple)
@htmlize.register(list)
def html_list(l):
    items = ('<li>{0}</li>'.format(htmlize(item)) for item in l)
    return '<ul>\n' + '\n'.join(items) + '\n</ul>'

# %%
print(htmlize([100, 300, 'python_rocks']))
# Out:
# <ul>
# <li>100(<i>0x64</i>)</li>
# <li>300(<i>0x12c</i>)</li>
# <li>python_rocks</li>
# </ul>

# %%
htmlize.dispatch(int)
# Out:
# <function __main__.html_int(a)>

# %%
from numbers import Integral

# %%
class Person:
    pass

# %%
class Student(Person):
    pass

# %%
p = Student()

# %%
type(p)
# Out:
# __main__.Student

# %%
isinstance(p, Student)
# Out:
# True

# %%
isinstance(p, Person)
# Out:
# True

# %%
@htmlize.register(Integral)
def html_integral_number(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))

# %%
htmlize('10')
# Out:
# '10'

# %%
@htmlize.register(int)
@htmlize.register(bool)
def html_integral_number(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))

# %%
htmlize(False)
# Out:
# 'False(<i>0x0</i>)'

# %%
from collections.abc import Sequence

# %%
isinstance((1,2,3), Sequence)
# Out:
# True

# %%
isinstance([1,2,3], Sequence)
# Out:
# True

# %%
from functools import singledispatch

# %%
from numbers import Integral
from collections.abc import Sequence

# %%
@singledispatch
def htmlize(a):
    return escape(str(a))

# %%
@htmlize.register(Integral)
def html_int(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))

# %%
htmlize.registry
# Out:
# mappingproxy({object: <function __main__.htmlize(a)>,
#               numbers.Integral: <function __main__.html_int(a)>})

# %%
@htmlize.register(Sequence)
def html_list(l):
    items = ('<li>{0}</li>'.format(htmlize(item)) for item in l)
    return '<ul>\n' + '\n'.join(items) + '\n</ul>'

# %%
htmlize.registry
# Out:
# mappingproxy({object: <function __main__.htmlize(a)>,
#               numbers.Integral: <function __main__.html_int(a)>,
#               collections.abc.Sequence: <function __main__.html_list(l)>})

# %%
htmlize([1,2,3])
# Out:
# '<ul>\n<li>1(<i>0x1</i>)</li>\n<li>2(<i>0x2</i>)</li>\n<li>3(<i>0x3</i>)</li>\n</ul>'

# %%
print(htmlize((1,2,3)))
# Out:
# <ul>
# <li>1(<i>0x1</i>)</li>
# <li>2(<i>0x2</i>)</li>
# <li>3(<i>0x3</i>)</li>
# </ul>

# %%
print(htmlize('python')) # since string is a sequence we get maximum recursion depth exceeded
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[523], line 1
# ----> 1 print(htmlize('python'))
#
# File ~/miniconda3/envs/tf2.11/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# Cell In[516], line 4, in html_list(l)
#       1 @htmlize.register(Sequence)
#       2 def html_list(l):
#       3     items = ('<li>{0}</li>'.format(htmlize(item)) for item in l)
# ----> 4     return '<ul>\n' + '\n'.join(items) + '\n</ul>'
#
# Cell In[516], line 3, in <genexpr>(.0)
#       1 @htmlize.register(Sequence)
#       2 def html_list(l):
# ----> 3     items = ('<li>{0}</li>'.format(htmlize(item)) for item in l)
# ...

# %%
def html_escape(arg):
    return escape(str(arg))

# %%
@htmlize.register(str)
def html_str(s):
    return html_escape(s).replace('\n', '<br/>\n')

# %%
print(htmlize('python'))
# Out:
# python

# %%
@htmlize.register(tuple)
def html_tuple(t):
    items = (escape(str(item)) for item in t)
    return '({0})'.format(', '.join(items))

# %%
htmlize.registry
# Out:
# mappingproxy({object: <function __main__.htmlize(a)>,
#               numbers.Integral: <function __main__.html_int(a)>,
#               collections.abc.Sequence: <function __main__.html_list(l)>,
#               str: <function __main__.html_str(s)>,
#               tuple: <function __main__.html_tuple(t)>})

# %%
htmlize((1,2,3))
# Out:
# '(1, 2, 3)'

# %%
print(htmlize(100))
# Out:
# 100(<i>0x64</i>)

# %%
print(htmlize(True))
# Out:
# True(<i>0x1</i>)

# %%
@htmlize.register(Integral)
def _(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))

@htmlize.register(Sequence)
def _(l):
    items = ('<li>{0}</li>'.format(htmlize(item)) for item in l)
    return '<ul>\n' + '\n'.join(items) + '\n</ul>'
    
@htmlize.register(str)
def _(s):
    return html_escape(s).replace('\n', '<br/>\n')

# %%
htmlize.dispatch(Sequence)
# Out:
# <function __main__._(l)>

# %%
htmlize.dispatch(Integral)
# Out:
# <function __main__._(a)>

# %%
from html import escape
def singledispatch(fn):
    registry = {}
    registry[object] = fn
    def decorated(arg):
        return registry.get(type(arg), registry[object])(arg)
    def register(type_):
        def inner(fn):
            registry[type_] = fn
            return fn
        return inner
    decorated.register = register  
    decorated.registry = registry
    return decorated

# %%
def htmlize(a):
    return escape(str(a))

# %%
def html_list(l):
    items = ('<li>{0}</li>'.format(f1(item)) for item in l)
    return '<ul>\n' + '\n'.join(items) + '\n</ul>'

# %%
def html_int(a):
    return '{0}(<i>{1}</i>)'.format(a, str(hex(a)))

# %%
f1 = singledispatch(htmlize)

# %%
f1.register(int)(html_int)
# Out:
# <function __main__.html_int(a)>

# %%
f1.registry
# Out:
# {object: <function __main__.htmlize(a)>, int: <function __main__.html_int(a)>}

# %%
f1.register(tuple)(html_list)
# Out:
# <function __main__.html_list(l)>

# %%
f1.register(list)(html_list)
# Out:
# <function __main__.html_list(l)>

# %%
f1((100, 300, 'python_rocks'))
# Out:
# '<ul>\n<li>100(<i>0x64</i>)</li>\n<li>300(<i>0x12c</i>)</li>\n<li>python_rocks</li>\n</ul>'

# %%
print(f1((100, 300, 'python_rocks')))
# Out:
# <ul>
# <li>100(<i>0x64</i>)</li>
# <li>300(<i>0x12c</i>)</li>
# <li>python_rocks</li>
# </ul>

# %%
f1.registry
# Out:
# {object: <function __main__.htmlize(a)>,
#  int: <function __main__.html_int(a)>,
#  tuple: <function __main__.html_list(l)>,
#  list: <function __main__.html_list(l)>}

# %%
f1(100)
# Out:
# '100(<i>0x64</i>)'

# %%
print(f1((100, 300, 'python_rocks')))
# Out:
# <ul>
# <li>100(<i>0x64</i>)</li>
# <li>300(<i>0x12c</i>)</li>
# <li>python_rocks</li>
# </ul>

# %%
singledispatch(f1.register(tuple)).register(list)(html_list)((100, 300, 'python_rocks'))
# Out:
# '<ul>\n<li>100(<i>0x64</i>)</li>\n<li>300(<i>0x12c</i>)</li>\n<li>python_rocks</li>\n</ul>'

# %%
singledispatch(f1.register(tuple)).register(list)(html_list)([100, 300, 'python_rocks'])
# Out:
# '<ul>\n<li>100(<i>0x64</i>)</li>\n<li>300(<i>0x12c</i>)</li>\n<li>python_rocks</li>\n</ul>'
